# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguaje Natural
#
# ## Taller #3: Web Scraping
# `Fecha de entrega: Marzo 11, 2021. (Antes del inicio de la próxima clase).`

# %% [markdown]
# # Punto 1:
#
# - `[15 pts]` Hacer Web Scraping de 10 animales en Wikipedia (en búcle)
# - `[10 pts]` Obtener el **encabezado** de cada animal
# - `[15 pts]` Obtener todos los **textos** que están en las etiquetas de negrilla del primer párrafo.

# %%
#import libreria request
import urllib.request
import bs4 as bs

# %%
link1 = "https://es.wikipedia.org/wiki/Aves"
link2 = "https://es.wikipedia.org/wiki/Anthophila"
link3 = "https://es.wikipedia.org/wiki/Chiroptera"
link4 = "https://es.wikipedia.org/wiki/Lacertilia"
link5 = "https://es.wikipedia.org/wiki/Iguanidae"
link6 = "https://es.wikipedia.org/wiki/Phocidae"
link7 = "https://es.wikipedia.org/wiki/Giraffa_camelopardalis"
link8 = "https://es.wikipedia.org/wiki/Chamaeleonidae"
link9 = "https://es.wikipedia.org/wiki/Phascolarctos_cinereus"
link10 = "https://es.wikipedia.org/wiki/Rhinocerotidae"

# %%
Links=["https://es.wikipedia.org/wiki/Aves","https://es.wikipedia.org/wiki/Anthophila",
      "https://es.wikipedia.org/wiki/Chiroptera","https://es.wikipedia.org/wiki/Lacertilia",
      "https://es.wikipedia.org/wiki/Iguanidae","https://es.wikipedia.org/wiki/Phocidae",
       "https://es.wikipedia.org/wiki/Giraffa_camelopardalis","https://es.wikipedia.org/wiki/Chamaeleonidae",
      "https://es.wikipedia.org/wiki/Phascolarctos_cinereus",
      "https://es.wikipedia.org/wiki/Rhinocerotidae"]
Links
# Out:
# ['https://es.wikipedia.org/wiki/Aves',
#  'https://es.wikipedia.org/wiki/Anthophila',
#  'https://es.wikipedia.org/wiki/Chiroptera',
#  'https://es.wikipedia.org/wiki/Lacertilia',
#  'https://es.wikipedia.org/wiki/Iguanidae',
#  'https://es.wikipedia.org/wiki/Phocidae',
#  'https://es.wikipedia.org/wiki/Giraffa_camelopardalis',
#  'https://es.wikipedia.org/wiki/Chamaeleonidae',
#  'https://es.wikipedia.org/wiki/Phascolarctos_cinereus',
#  'https://es.wikipedia.org/wiki/Rhinocerotidae']

# %%
#Descargar la pagina web en python
for i in Links:    
    request=urllib.request.urlopen(i)
    fuente=request.read()
    request.close()
    soup=bs.BeautifulSoup(fuente,'html.parser')
    print(soup.find(id='firstHeading').contents)
# Out:
# ['Aves']
# ['Anthophila']
# ['Chiroptera']
# ['Lacertilia']
# ['Iguanidae']
# ['Phocidae']
# ['Giraffa camelopardalis']
# ['Chamaeleonidae']
# ['Phascolarctos cinereus']
# ['Rhinocerotidae']

# %%
#soup.h1
# Out:
# <h1 class="firstHeading" id="firstHeading">Rhinocerotidae</h1>

# %%
#text1 = soup.find_all('p')[1]

# %%
#text1
# Out:
# <p>Las <b>aves</b> son <a href="/wiki/Animalia" title="Animalia">animales</a> <a class="mw-redirect" href="/wiki/Vertebrado" title="Vertebrado">vertebrados</a>, de <a href="/wiki/Homeotermia" title="Homeotermia">sangre caliente</a>, que <a href="/wiki/Bipedestaci%C3%B3n" title="Bipedestación">caminan, saltan o se mantienen solo sobre las extremidades posteriores</a>,<sup class="reference separada" id="cite_ref-4"><a href="#cite_note-4"><span class="corchete-llamada">[</span>3<span class="corchete-llamada">]</span></a></sup>​ mientras que las extremidades anteriores han evolucionado hasta convertirse en <a class="mw-redirect" href="/wiki/Ala_(animal)" title="Ala (animal)">alas</a> que, al igual que muchas otras características <a href="/wiki/Anatom%C3%ADa_de_las_aves" title="Anatomía de las aves">anatómicas</a> únicas, les permiten, en la mayoría de los casos, <a href="/wiki/Vuelo_de_las_aves" title="Vuelo de las aves">volar</a>, si bien <a href="/wiki/Ave_no_voladora" title="Ave no v
# ...

# %%
#text1.find_all(title="Animalia")
#text1.find_all("a").get("title") error
#text1.find("b").text
# Out:
# 'aves'

# %%
Links = []
for i in Links :
    value = bs.BeautifulSoup(n,'html.parser').find('p').find_('b')
    if len(value) == 0:
        value = bs.BeautifulSoup(n, 'html.parser').find(class_=("mw-parser-output").find_all('p')[1].find_('b')
# Out:
#   File "<ipython-input-54-f78400172b24>", line 9
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # Punto 2:
# - `[10 pts]` Usando regex, reemplazar todas las caracteres especiales del punto anterior (palabras en negrilla) por un asterisco (¡Ojo, los espacios se quedan!)

# %%
import re
#patron = "*","áéíóú"
#re.serch(patron, texto)


for link in Links:
    request = urllib.request.Request(link, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urllib.request.urlopen(request)
    source = webpage.read()
    webpage.close()
    soup = bs.BeautifulSoup(source, 'html.parser')
    negritas = soup.find("body").find_all("b")
    listadoNegritas =[]   
    for val in negritas:
        listadoNegritas.append(val.text)
   
    print(f'Links_Scraping: {link}')
    print(f'Palabras con caracteres:')       
    i=1   
    for palabra in listadoNegritas:
        resultado = re.sub(r"[áéíóú]", "*", palabra)
        print(f'{i}. {resultado}')
        i+=1
# Out:
# Links_Scraping: https://es.wikipedia.org/wiki/Aves
# Palabras con caracteres:
# 1. Aves
# 2. aves
# 3. Aves
# 4. Aves
# 5. Aves
# 6. Subclase Neornithes
# 7. 11
# 8. a
# 9. b
# 10. c
# 11. d
# 12. a
# 13. b
# 14. 322
# 15. 317
# 16. 421
# 17. 82
# 18. 31
# 19. 27
# 20. 266
# 21. 120
# 22. a
# 23. b
# 24. c
# 25. d
# 26. e
# 27. 286
# 28. 433
# 29. a
# 30. b
# 31. 2
# 32. 3
# 33. a
# 34. b
# 35. c
# 36. d
# 37. 69
# 38. 13
# 39. 92
# 40. a
# 41. b
# 42. c
# 43. d
# 44. e
# 45. f
# 46. g
# 47. 149
# 48. 18
# 49. 526
# 50. 2
# 51. a
# 52. b
# 53. c
# 54. a
# 55. b
# 56. c
# 57. 31
# 58. 24
# 59. a
# 60. b
# 61. 320
# 62. 2
# 63. 8
# 64. 315
# 65. a
# 66. b
# 67. 205
# 68. 11
# 69. a
# 70. b
# 71. c
# 72. d
# 73. e
# 74. f
# 75. g
# 76. h
# 77. i
# 78. j
# 79. k
# 80. l
# 81. m
# 82. n
# 83. ñ
# 84. o
# 85. p
# 86. q
# 87. r
# 88. s
# 89. t
# 90. u
# 91. v
# 92. w
# 93. x
# 94. y
# 95. z
# 96. a
# 97. b
# 98. 208
# 99. 386
# 100. 76
# 101. 205
# 102. 96
# 103. 100
# 104. 73
# 105. 97
# ...
